# %%
import pandas as pd

# %%
data = pd.read_csv('Resources/One-Hot-Encoding-01.csv')

# %%
data
# Out:
#    result
# 0    Pass
# 1    Fail
# 2    Pass
# 3    Pass
# 4  Absent
# 5    Fail
# 6    Fail
# 7    Pass
# 8    Pass
# 9  Absent

# %%
data.result
# Out:
# 0      Pass
# 1      Fail
# 2      Pass
# 3      Pass
# 4    Absent
# 5      Fail
# 6      Fail
# 7      Pass
# 8      Pass
# 9    Absent
# Name: result, dtype: object
