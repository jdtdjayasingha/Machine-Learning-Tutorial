# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
data = np.array([[26, 50000], 
                 [29, 70000], 
                 [34, 55000], 
                 [31,41000]])

# %%
obj = MinMaxScaler()

# %%
scaled_data = obj.fit_transform(data)

# %%
scaled_data
# Out:
# array([[0.        , 0.31034483],
#        [0.375     , 1.        ],
#        [1.        , 0.48275862],
#        [0.625     , 0.        ]])

# %%
obj2 = StandardScaler()

# %%
scaled_data2 = obj2.fit_transform(data)

# %%
scaled_data2
# Out:
# array([[-1.37198868, -0.3805212 ],
#        [-0.34299717,  1.52208478],
#        [ 1.37198868,  0.0951303 ],
#        [ 0.34299717, -1.23669388]])
